# %% [markdown]
# # General

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import cv2
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (16, 16)

image = cv2.imread("/home/enacom/TestesVisao/SOURCES/pokemon3d.jpg")
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # PyrDown

# %% [markdown]
# Blurs an image and downsamples it.
# <br><br>
# The function performs the downsampling step of the Gaussian pyramid construction. First, it convolves the source image with the kernel:
#
# $$\frac{1}{256}\begin{bmatrix} 1&4&6&4&1\\4&16&24&16&4\\ 6&24&36&24&6\\4&16&24&16&4\\1&4&6&4&1 \end{bmatrix},$$
#
# <br><br>
# Then, it downsamples the image by rejecting even rows and columns.

# %% [markdown]
# <font size="4"> **dst	=	cv.pyrDown(	src[, dst[, dstsize[, borderType]]]	)**</font>

# %%
dst = cv2.pyrDown(image)
fig, axs = plt.subplots(1, 2)
axs[0].imshow(image)
axs[1].imshow(dst)

# %% [markdown]
# # pyrMeanShiftFiltering

# %% [markdown]
# <font size="5">
# Performs initial step of meanshift segmentation of an image.
#
# <br><br>
# At every pixel (X,Y) of the input image (or down-sized input image, see below) the function executes meanshift iterations, that is, the pixel (X,Y) neighborhood in the joint space-color hyperspace is considered:
#
# $$ x: X - sp \leq \textit{x} \leq X + sp$$
# $$ y: Y - sp \leq \textit{y} \leq Y + sp$$
# <br>
# $$ \left\lvert\lvert (R, G, B) - (r, g, b) \right\rvert\rvert \leq sr $$
# <br><br>
# Over the neighborhood the average spatial value (X',Y') and average color vector (R',G',B') are found and they act as the neighborhood center on the next iteration:
# <br>
# That means:
# $$ (x, y) => (X, Y)$$
# $$ (X, Y) => (X',Y')$$
# $$ (r, g, b) => (R, G, B)$$
# $$ (R, G, B) => (R',G', B')$$
# </font>

# %% [markdown]
# <font size="4"> **dst	=	cv.pyrMeanShiftFiltering(	src, sp, sr[, dst[, maxLevel[, termcrit]]]	)**</font>

# %%
dst = cv2.pyrMeanShiftFiltering(image, sp=21, sr=51, maxLevel=1, termcrit=(cv2.TERM_CRITERIA_EPS+cv2.TERM_CRITERIA_MAX_ITER, 5, 1))

fig, axs = plt.subplots(1, 2)
axs[0].imshow(image)
axs[1].imshow(dst)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-11-cdec1ee582c2> in <module>
# ----> 1 dst = cv2.pyrMeanShiftFiltering(image, sp=1, sr=1, dst=None, maxLevel=3, termcrit=5)
#       2
#       3 fig, axs = plt.subplots(1, 2)
#       4 axs[0].imshow(image)
#       5 axs[1].imshow(dst)
#
# SystemError: new style getargs format but argument is not a tuple

# %% [markdown]
# # pyrUp
