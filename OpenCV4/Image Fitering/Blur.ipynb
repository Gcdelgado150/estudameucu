# %% [markdown]
# 	dst	=	cv.blur(	src, ksize[, dst[, anchor[, borderType]]]	)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import cv2
import matplotlib.pyplot as plt
# Out:
# <style>.container { width:100% !important; }</style>

# %%
BORDERS_TYPES = [cv2.BORDER_CONSTANT,
                 cv2.BORDER_REPLICATE,
                 cv2.BORDER_REFLECT,
                 cv2.BORDER_WRAP,
                 cv2.BORDER_REFLECT_101,
                 cv2.BORDER_TRANSPARENT,
                 cv2.BORDER_REFLECT101,
                 cv2.BORDER_DEFAULT,
                 cv2.BORDER_ISOLATED,]

# %%
image = cv2.imread("/home/enacom/TestesVisao/SOURCES/pokemon3d.jpg")
plt.imshow(image)

# %%
blur = cv2.blur(image, (3,3), dst=None, anchor=(-1, -1), borderType=cv2.BORDER_CONSTANT)
plt.imshow(blur)

# %%
blur = cv2.blur(image, (7,7), dst=None, anchor=(-1, -1), borderType=BORDERS_TYPES[1])
plt.imshow(blur)
