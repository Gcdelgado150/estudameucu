# %% [markdown]
# # General

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import cv2
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (16, 16)

image = cv2.imread("/home/enacom/TestesVisao/SOURCES/pokemon3d.jpg")
# plt.imshow(image)
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # sqrBoxFilter

# %% [markdown]
# Calculates the normalized sum of squares of the pixel values overlapping the filter.
# <br><br>
# For every pixel (x,y) in the source image, the function calculates the sum of squares of those neighboring pixel values which overlap the filter placed over the pixel (x,y).
# <br><br>
# The unnormalized square box filter can be useful in computing local image statistics such as the the local variance and standard deviation around the neighborhood of a pixel.

# %% [markdown]
# <font size="4">**dst	=	cv.sqrBoxFilter(	src, ddepth, ksize[, dst[, anchor[, normalize[, borderType]]]]	)**</font>

# %%
dst = cv2.sqrBoxFilter(image[:,:,0], ddepth=-1, ksize=(5,5), anchor=(-1, -1))
plt.imshow(dst)

# %%
dst = cv2.sqrBoxFilter(image[:,:,1], ddepth=-1, ksize=(3, 3), anchor=(-1, -1))
plt.imshow(dst)

# %%
dst = cv2.sqrBoxFilter(image[:,:,2], ddepth=-1, ksize=(5, 5), anchor=(-1, -1))
plt.imshow(dst)

# %% [markdown]
# ## Trying filter simple

# %%
image.dtype
# Out:
# dtype('uint8')

# %%
test_image = np.array([[1,2,1,2,1],[1,2,3,2,1],[1,2,1,2,1],[1,2,3,2,1],[1,2,1,2,1]], dtype="float32")

# %%
new = cv2.sqrBoxFilter(test_image, ddepth=-1, ksize=(3, 3), anchor=(-1, -1), normalize=True, borderType=cv2.BORDER_CONSTANT)
new2 = cv2.sqrBoxFilter(test_image, ddepth=-1, ksize=(3, 3), anchor=(-1, -1))

fig, axs = plt.subplots(1, 3)
axs[0].imshow(test_image)
axs[1].imshow(new)
axs[2].imshow(new2)
plt.show()

# %%
test_image
# Out:
# array([[1., 2., 1., 2., 1.],
#        [1., 2., 3., 2., 1.],
#        [1., 2., 1., 2., 1.],
#        [1., 2., 3., 2., 1.],
#        [1., 2., 1., 2., 1.]], dtype=float32)

# %%
new
# Out:
# array([[1.11111111, 2.22222222, 2.88888889, 2.22222222, 1.11111111],
#        [1.66666667, 2.88888889, 3.88888889, 2.88888889, 1.66666667],
#        [1.66666667, 3.77777778, 4.77777778, 3.77777778, 1.66666667],
#        [1.66666667, 2.88888889, 3.88888889, 2.88888889, 1.66666667],
#        [1.11111111, 2.22222222, 2.88888889, 2.22222222, 1.11111111]])

# %%
new2
# Out:
# array([[3.        , 3.77777778, 4.77777778, 3.77777778, 3.        ],
#        [3.        , 2.88888889, 3.88888889, 2.88888889, 3.        ],
#        [3.        , 3.77777778, 4.77777778, 3.77777778, 3.        ],
#        [3.        , 2.88888889, 3.88888889, 2.88888889, 3.        ],
#        [3.        , 3.77777778, 4.77777778, 3.77777778, 3.        ]])

# %%
test_image[:3, :3]
# Out:
# array([[1, 2, 1],
#        [1, 2, 3],
#        [1, 2, 1]], dtype=uint8)

# %%
alls = []
for value in test_image[:3, :3]:
    for x in value:
        alls.append(x*x)

# %%
sum(alls)
# Out:
# 26

# %%
np.mean(test_image[:3, :3])
# Out:
# 22.22222222222222

# %%
new[1, 1]
# Out:
# 955.55554
